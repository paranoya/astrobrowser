# %% [markdown]
# # AstroBrowser Data Explorer
#
# Notebook edition

# %% [markdown]
# # 1. Initialisation

# %%
# %matplotlib ipympl

from astropy.table import Table
from scripts import astrobrowser

import importlib

# %% [markdown]
# ## Read input catalogue

# %%
catalogue = Table.read('HiPS_target_list.csv')

# %%
catalogue
# Out:
# <Table length=87>
#            ID               RA        DEC    RADIUS_ARCSEC PIXEL_SIZE_ARCSEC
#          str23           float64    float64     float64         float64
# ----------------------- ---------- --------- ------------- -----------------
# WA_J000013.30+330803.00   0.055417 33.134167          87.3               1.5
# WA_J000250.21+312905.60   0.709208 31.484889          89.0               1.5
# WA_J020011.19+373612.10  30.046625 37.603361         109.2               1.8
# WA_J020126.54+284403.50  30.360583 28.734306          85.5               1.4
# WA_J020344.83+381531.40  30.936792 38.258722          75.8               1.3
# WA_J021612.79+323858.20  34.053292   32.6495          91.6               1.5
#                     ...        ...       ...           ...               ...
# WA_J224939.09+440008.30 342.412875 44.002306          49.2               0.8
# WA_J230722.85+433614.20 346.845208 43.603944          95.0               1.6
# WA_J234939.90+295555.50  357.41625 29.932083          83.3               1.4
# WA_J234947.56+300220.80 357.448167 30.039111          85.8               1.4
# WA_J235209.89+311635.80 358.041208 31.276611          51.5               0.9
# WA_J235224.45+284621.60 358.101875 28.772667          64.8               1.1
# WA_J235723.99+305931.80 359.349958 30.992167          93.7               1.6

# %% [markdown]
# # 2. Explore available skymaps

# %% [markdown]
# Select the maps for this galaxy:

# %%
importlib.reload(astrobrowser)
x = astrobrowser.DataExplorer(catalogue, 'CDS/P/PanSTARRS/DR1/r')
# Out:
# interactive(children=(BoundedIntText(value=0, description='galaxy_index', max=87), Combobox(value='CDS/P/PanST…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
catalogue[18]
# Out:
# <Row index=18>
#            ID               RA       DEC    RADIUS_ARCSEC PIXEL_SIZE_ARCSEC
#          str23           float64   float64     float64         float64
# ----------------------- --------- --------- ------------- -----------------
# WA_J023342.96+403141.22 38.428991 40.528116         871.0              14.5
